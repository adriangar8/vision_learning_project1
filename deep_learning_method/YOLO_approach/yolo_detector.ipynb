# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\polme\appdata\roaming\python\python311\site-packages (2.0.1)
# Requirement already satisfied: torchvision in c:\users\polme\appdata\roaming\python\python311\site-packages (0.15.2)
# Requirement already satisfied: torchaudio in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in c:\users\polme\appdata\roaming\python\python311\site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torchvision) (1.26.0)
# Requirement already satisfied: requests in c:\users\polme\appdata\roaming\python\python311\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torchvision) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\polme\appdata\roaming\python\python311\site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from requests->torchvision) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\polme\appdata\roaming\python\python311\site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from sympy->torch) (1.3.0)

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# Collecting gitpython>=3.1.30 (from -r requirements.txt (line 5))
#   Obtaining dependency information for gitpython>=3.1.30 from https://files.pythonhosted.org/packages/8a/7e/20f7e45878b5aed34320fbeeae8f78acc806e7bd708d00b1c6e64b016f5b/GitPython-3.1.37-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.37-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 6)) (3.8.0)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 7)) (1.26.0)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 8)) (4.8.0.76)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 9)) (10.0.1)
# Requirement already satisfied: psutil in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\polme\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 12)) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 13)) (1.11.2)
# Collecting thop>=0.1.1 (from -r requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in c:\users\polme\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\polme\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 16)) (0.15.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 17)) (4.66.1)
# Collecting ultralytics>=8.0.147 (from -r requirements.txt (line 18))
#   Obtaining dependency information for ultralytics>=8.0.147 from https://files.pythonhosted.org/packages/0d/0d/702882bdf7ced799b17c69ab0663ae87a7b499fd1916fe469dd764b380bb/ultralytics-8.0.188-py3-none-any.whl.metadata
#   Downloading ultralytics-8.0.188-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 27)) (2.1.1)
# Collecting seaborn>=0.11.0 (from -r requirements.txt (line 28))
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: setuptools>=65.5.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from -r requirements.txt (line 42)) (68.0.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r requirements.txt (line 5))
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\polme\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\polme\appdata\roaming\python\python311\site-packages (from requests>=2.23.0->-r requirements.txt (line 12)) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\polme\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.12.4)
# Requirement already satisfied: typing-extensions in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.7.1)
# Requirement already satisfied: sympy in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.12)
# Requirement already satisfied: networkx in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: colorama in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from tqdm>=4.64.0->-r requirements.txt (line 17)) (0.4.6)
# Collecting py-cpuinfo (from ultralytics>=8.0.147->-r requirements.txt (line 18))
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5))
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\polme\anaconda3\envs\licenseplates\lib\site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Downloading GitPython-3.1.37-py3-none-any.whl (190 kB)
#    ---------------------------------------- 0.0/190.0 kB ? eta -:--:--
#    -------------------------------------- - 184.3/190.0 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 190.0/190.0 kB 3.8 MB/s eta 0:00:00
# Downloading ultralytics-8.0.188-py3-none-any.whl (615 kB)
#    ---------------------------------------- 0.0/615.5 kB ? eta -:--:--
#    ---------- ----------------------------- 163.8/615.5 kB 9.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 348.2/615.5 kB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 553.0/615.5 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 615.5/615.5 kB 4.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: py-cpuinfo, smmap, gitdb, thop, seaborn, gitpython, ultralytics
# Successfully installed gitdb-4.0.10 gitpython-3.1.37 py-cpuinfo-9.0.0 seaborn-0.12.2 smmap-5.0.1 thop-0.1.1.post2209072238 ultralytics-8.0.188

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
import os
os.environ['TORCH_HOME'] = 'deep_learning_method\YOLO_approach\cache'

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in deep_learning_method\YOLO_approach\cache\hub\ultralytics_yolov5_master
# YOLOv5  2023-9-29 Python-3.11.5 torch-2.0.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode='nearest')
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode='nearest')
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )
