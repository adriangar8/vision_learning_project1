# %%
import torch

# %%
model = torch.models.detection.fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/adrian/Documents/academia/UAB/year_3/vision_learning/project1/project1_repo/deep_learning_method/RCNN_approach/RCNN.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/home/adrian/Documents/academia/UAB/year_3/vision_learning/project1/project1_repo/deep_learning_method/RCNN_approach/RCNN.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> model = torch.models.detection.fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
#
# AttributeError: module 'torch' has no attribute 'models'
